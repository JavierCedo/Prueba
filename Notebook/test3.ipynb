# %% [markdown]
# # Nuevo test para probar el guardar en un repositorio online en github
# ## Sets in Python

# %%
import pylab
import numpy as np

x = np.linspace(1,10,100)
y = x

pylab.plot(x,y)
pylab.show()
